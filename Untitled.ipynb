# %%
import random

class unoCard:
    def __init__(self, color, number, skip=False):
        self.color=color
        self.number=number
        self.skip=skip

    def __str__(self):
        if self.skip:
            return f"{self.color} Skipped"
        return f"{self.color} {self.number}" 
        
def deckGeneration():
    colors=["Red", "Blue", "Green", "Yellow"]
    deck=[]

    for c in colors:
        for n in range(10):
            deck.append(unoCard(c, n))
        deck.append(unoCard(c, None, skip=True))

    random.shuffle(deck)
    return deck

def cardDealing(deck):
    return [deck.pop() for x in range(5)]

# %%
def validMoves(hand, topCard):
    valid=[]

    for card in hand:
        if card.color==topCard.color or card.number==topCard.number or card.skip:
            valid.append(card)

    return valid

class gameState:
    def __init__(self, p1, p2, p3, topCard, deck):
        self.p1=p1
        self.p2=p2
        self.p3=p3
        self.topCard=topCard
        self.deck=deck

def cardMovement(state, player, move):
    newState=gameState(state.p1[:], state.p2[:], state.p3[:], state.topCard,
                       state.deck[:])

    hand=getattr(newState, player)

    if move is None:
        if newState.deck:
            hand.append(newState.deck.pop())

        return newState

    hand.remove(move)
    newState.topCard=move

    return newState

def evaluationFunction(state, player="p1"):
    aiCards=len(getattr(state, player))

    opponents=[]
    for p in ["p1", "p2", "p3"]:
        if p!=player:
            opponents.append(len(getattr(state, p)))

    avgOpponent=sum(opponents)/2
    skipCards=sum(1 for c in getattr(state, player) if c.skip)
    score=50 - 5*aiCards + 2*avgOpponent + 3*skipCards
    return score

def minimax(state, depth, maximizing, player):
    if depth==0:
        return evaluationFunction(state, "p1")

    hand=getattr(state, player)
    validMove=validMoves(hand, state.topCard)

    if not validMove:
        validMove=[None]

    if maximizing:
        best=float('-inf')
        for move in validMove:
            newState=cardMovement(state, player, move)
            val=minimax(newState, depth-1, False, "p2")
            best=max(best, val)
        return best
    else:
        best=float('inf')
        for move in validMove:
            newState=cardMovement(state, player, move)
            val=minimax(newState, depth-1, True, "p1")
            best=min(best, val)
        return best

def expectimax(state, depth, nodeType):
    if depth==0:
        return evaluationFunction(state, "p2")

    validMove1=validMoves(state.p1, state.topCard)
    validMove2=validMoves(state.p2, state.topCard)

    if not validMove1:
        validMove1=[None]
    if not validMove2:
        validMove2=[None]
        
    if nodeType=="max":
        best=float('-inf')
        for move in validMove2:
            newState=cardMovement(state, "p2", move)
            val=expectimax(newState, depth-1, "chance")
            best=max(best, val)
        
        return best
    
    elif nodeType=="chance":
        if not state.deck:
            return evaluationFunction(state, "p2")

        prob=1/len(state.deck)
        total=0

        for card in state.deck:
            newState=cardMovement(state, "p2", None)
            total+=prob * expectimax(newState, depth-1, "opponent")
        
        return total
    
    elif nodeType=="opponent":
        move=random.choice(validMove1)
        newState=cardMovement(state, "p1", move)

        return expectimax(newState, depth-1, "max")

def gameLoop():
    deck=deckGeneration()

    p1=cardDealing(deck)
    p2=cardDealing(deck)
    p3=cardDealing(deck)

    topCard=deck.pop()

    skipNext=False

    state=gameState(p1, p2, p3, topCard, deck)

    turn=0

    while True:
        print("\nThe top card is:", state.topCard)

        if turn==0:
            print("Player 1 (MINIMAX)")
            moves=validMoves(state.p1, state.topCard)

            bestMove=None
            bestScore=float('-inf')

            for move in moves or [None]:
                newState=cardMovement(state, "p1", move)
                score=minimax(newState, 3, False, "p2")

                print(f"Move: {move}, Score: {score}")

                if score>bestScore:
                    bestScore=score
                    bestMove=move

            state=cardMovement(state, "p1", bestMove)
            if state.topCard.skip:
                skipNext=True

        elif turn==1:
            print("Player 2 (EXPECTIMAX)")
            moves=validMoves(state.p2, state.topCard)

            bestMove=None
            bestScore=float('-inf')

            for move in moves or [None]:
                newState=cardMovement(state, "p2", move)
                score=expectimax(newState, 3, "chance")

                print(f"Move: {move}, Score: {score}")

                if score>bestScore:
                    bestScore=score
                    bestMove=move

            state=cardMovement(state, "p2", bestMove)
            if state.topCard.skip:
                skipNext=True

        else:
            print("Player 3 (RANDOM)")
            moves=validMoves(state.p3, state.topCard) or [None]
            move=random.choice(moves)
            state=cardMovement(state, "p3", move)
            if state.topCard.skip:
                skipNext=True
            
        if len(state.p1)==0:
            print("Player 1 wins :)")
            break
        if len(state.p2)==0:
            print("Player 2 wins :)")
            break
        if len(state.p3)==0:
            print("Player 3 wins :)")
            break

        if skipNext:
            print(f"Player {(turn+1)%3 +1} is skipped :(")
            turn=(turn+2)%3
            skipNext=False
        else:
            turn=(turn+1)%3

# %%
gameLoop()
# Out:
# The top card is: Red 9
# Player 1 (MINIMAX)
# Move: Green Skipped, Score: 43.0
# Move: Red 2, Score: 46.0
#
# The top card is: Red 2
# Player 2 (EXPECTIMAX)
# Move: Red 0, Score: 37.99999999999999
# Move: Green 2, Score: 37.99999999999999
#
# The top card is: Red 0
# Player 3 (RANDOM)
#
# The top card is: Red 3
# Player 1 (MINIMAX)
# Move: Green Skipped, Score: 46.0
# Move: Green 3, Score: 46.0
# Player 2 is skipped :(
#
# The top card is: Green Skipped
# Player 3 (RANDOM)
# Player 1 is skipped :(
#
# The top card is: Green Skipped
# Player 2 (EXPECTIMAX)
# Move: Green 8, Score: 42.00000000000002
# Move: Green 2, Score: 42.00000000000002
#
# The top card is: Green 8
# Player 3 (RANDOM)
#
# The top card is: Blue 8
# Player 1 (MINIMAX)
# Move: None, Score: 40.0
#
# The top card is: Blue 8
# Player 2 (EXPECTIMAX)
# Move: Blue 3, Score: 49.99999999999997
# Move: Blue 7, Score: 46.999999999999986
#
# The top card is: Blue 3
# Player 3 (RANDOM)
#
# The top card is: Blue 9
# Player 1 (MINIMAX)
# Move: None, Score: 38.0
#
# The top card is: Blue 9
# Player 2 (EXPECTIMAX)
# Move: Blue 7, Score: 51.99999999999997
#
# The top card is: Blue 7
# Player 3 (RANDOM)
#
# The top card is: Blue 7
# Player 1 (MINIMAX)
# Move: Yellow 7, Score: 43.0
# Move: Blue Skipped, Score: 32.0
#
# The top card is: Yellow 7
# Player 2 (EXPECTIMAX)
# Move: None, Score: 46.999999999999986
#
# The top card is: Yellow 7
# Player 3 (RANDOM)
# Player 1 is skipped :(
#
# The top card is: Red Skipped
# Player 2 (EXPECTIMAX)
# Move: None, Score: 41.000000000000014
# Player 3 is skipped :(
#
# The top card is: Red Skipped
# Player 1 (MINIMAX)
# Move: Blue Skipped, Score: 44.0
# Player 2 is skipped :(
#
# The top card is: Blue Skipped
# Player 3 (RANDOM)
# Player 1 is skipped :(
#
# The top card is: Blue Skipped
# Player 2 (EXPECTIMAX)
# Move: Blue 0, Score: 45.99999999999999
#
# The top card is: Blue 0
# Player 3 (RANDOM)
#
# The top card is: Blue 2
# Player 1 (MINIMAX)
# Move: None, Score: 40.0
#
# The top card is: Blue 2
# Player 2 (EXPECTIMAX)
# Move: Green 2, Score: 45.499999999999986
#
# The top card is: Green 2
# Player 3 (RANDOM)
#
# The top card is: Yellow 2
# Player 1 (MINIMAX)
# Move: Yellow 6, Score: 43.0
# Move: Yellow 1, Score: 43.0
#
# The top card is: Yellow 6
# Player 2 (EXPECTIMAX)
# Move: Yellow 4, Score: 54.00000000000002
# Player 2 wins :)
